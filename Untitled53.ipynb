# %% [markdown]
# <a href="https://colab.research.google.com/github/wareefsaeed2009-dotcom/final_project/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_package="""pandas
numpy
seaborn
matplotlib"""
with open("requirements.txt","w") as f:
    f.write(python_package)
print("Done")
# Out:
# Done
